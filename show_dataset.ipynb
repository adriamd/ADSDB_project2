# %%
import duckdb
import pandas as pd

# %%
con = duckdb.connect('data/exploitation.db', read_only=True)

# %%
con.execute("show tables").df()
# Out:
#                                       name
# 0                                   houses
# 1  sandbox_T_apartment_condo_S_ga_fl_nc_sc

# %%
#con.execute("show select * from  houses").df()
con.execute("select * from  houses limit 10").df()
# Out:
#            id                                                url    region  \
# 0  7051152434  https://portland.craigslist.org/wsc/apa/d/port...  portland
# 1  7051146105  https://portland.craigslist.org/mlt/apa/d/port...  portland
# 2  7051135375  https://portland.craigslist.org/wsc/apa/d/hill...  portland
# 3  7051134300  https://portland.craigslist.org/clc/apa/d/wils...  portland
# 4  7051104814  https://portland.craigslist.org/mlt/apa/d/port...  portland
# 5  7051112739  https://portland.craigslist.org/clk/apa/d/vanc...  portland
# 6  7039764729  https://portland.craigslist.org/mlt/apa/d/port...  portland
# 7  7051064155  https://portland.craigslist.org/clc/apa/d/wils...  portland
# 8  7051050052  https://portland.craigslist.org/mlt/apa/d/port...  portland
# 9  7045835490  https://portland.craigslist.org/mlt/apa/d/gres...  portland
#
#                         region_url   price       type  sqfeet  beds  baths  \
# ...

# %%
con.close()
